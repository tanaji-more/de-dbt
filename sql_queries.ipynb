# %%
import duckdb
import pandas as pd

# %%
sql_query = '''
SELECT * FROM parking_violation_codes ;
'''

with duckdb.connect('data/nyc_parking_violations.db') as conn:
    display(conn.sql(sql_query).df())
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[9], line 5
#       1 sql_query = '''
#       2 SELECT * FROM parking_violations_codes ;
#       3 '''
# ----> 5 with duckdb.connect('data/nyc_parking_violations.db') as conn:
#       6     display(conn.sql(sql_query).df())
#
# Cell In[9], line 6
#       1 sql_query = '''
#       2 SELECT * FROM parking_violations_codes ;
#       3 '''
#       5 with duckdb.connect('data/nyc_parking_violations.db') as conn:
# ----> 6     display(conn.sql(sql_query).df())
#
# CatalogException: Catalog Error: Table with name parking_violations_codes does not exist!
# Did you mean "parking_violation_codes"?

# %%
sql_query_import_1 = '''
CREATE OR REPLACE TABLE parking_violation_codes AS 
SELECT * 
FROM read_csv_auto('data/dof_parking_violation_codes.csv',
normalize_names=TRUE)
'''

sql_query_import_2 = ''' 
CREATE OR REPLACE TABLE parking_violations_2023 AS
SELECT * FROM read_csv_auto(
'data/parking_violations_issued_fiscal_year_2023_sample.csv',
normalize_names=TRUE)
'''

with duckdb.connect('data/nyc_parking_violations.db') as conn:
    conn.sql(sql_query_import_1)
    conn.sql(sql_query_import_2)
